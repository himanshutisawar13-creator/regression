# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshutisawar13-creator/regression/blob/main/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[20,25,26,25,30,34,40,40,40,80]
y=[21,28,27,26,33,36,31,35,41,95]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats
x=[20,25,26,25,30,34,40,40,40,80]
y=[21,28,27,26,33,36,31,35,41,95]
slope,  intercept, r, p,std_err = stats.linregress(x, y)
def myfunc(x):
  return slope * x + intercept
mymodel = list(map(myfunc, x))
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
slope,
# Out:
# np.float64(1.196796338672769)

# %%
 intercept, r, p,std_err
# Out:
# (np.float64(-5.784668192219684),
#  np.float64(0.9696770757808743),
#  np.float64(3.5659155691211863e-06),
#  np.float64(0.10664271307298083))
