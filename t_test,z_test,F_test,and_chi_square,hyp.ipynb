# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshutisawar13-creator/regression/blob/main/t_test%2Cz_test%2CF_test%2Cand_chi_square%2Chyp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import stats
import numpy as np

#One-sample t-test
sample_data = np.array([10, 12, 11, 13, 10, 9, 12, 11, 10, 13])
population_mean = 10.5
t_statistic, p_value = stats.ttest_1samp(sample_data, population_mean)
print(f"one-sample t-test: t-statistic = {t_statistic:.2f}, p-value = {p_value:.3f}")
# Out:
# one-sample t-test: t-statistic = 1.38, p-value = 0.200

# %%
#Two-sample independent t-test
group1 = np.array([25, 28, 27, 26, 29])
group2 = np.array([22, 24, 23, 21, 25])
t_statistic, p_value = stats.ttest_ind(group1, group2)
print(f"two-sample independent t-test: t-statistic = {t_statistic:.2f}, p-value = {p_value:.3f}")
# Out:
# two-sample independent t-test: t-statistic = 4.00, p-value = 0.004

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

#Generate example data for two groups
np.random.seed(42)
group_a = np.random.normal(loc=50, scale=10, size=100)
group_b = np.random.normal(loc=55, scale=10, size=100)

#Perform independent samples t-test
t_statistic, p_value = stats.ttest_ind(group_a, group_b, equal_var=True)

#create a figure and axes for the plot
plt.figure(figsize=(10, 6))

#plot histograms of the two groups
sns.histplot(group_a, color='skyblue', label='Group A', kde=True, stat='density',alpha=0.6)
sns.histplot(group_b, color='salmon', label='Group B', kde=True, stat='density',alpha=0.6)

#Add vertical line for the mean of each group
plt.axvline(np.mean(group_a), color='blue', linestyle='--',linewidth=2, label=' Mean Group A')
plt.axvline(np.mean(group_b), color='blue', linestyle='--', linewidth=2,  label='Mean Group B ')

#

# %%
group_a
# Out:
# array([54.96714153, 48.61735699, 56.47688538, 65.23029856, 47.65846625,
#        47.65863043, 65.79212816, 57.67434729, 45.30525614, 55.42560044,
#        45.36582307, 45.34270246, 52.41962272, 30.86719755, 32.75082167,
#        44.37712471, 39.8716888 , 53.14247333, 40.91975924, 35.87696299,
#        64.65648769, 47.742237  , 50.67528205, 35.75251814, 44.55617275,
#        51.1092259 , 38.49006423, 53.75698018, 43.9936131 , 47.0830625 ,
#        43.98293388, 68.52278185, 49.86502775, 39.42289071, 58.22544912,
#        37.7915635 , 52.08863595, 30.40329876, 36.71813951, 51.96861236,
#        57.3846658 , 51.71368281, 48.84351718, 46.98896304, 35.2147801 ,
#        42.80155792, 45.39361229, 60.57122226, 53.4361829 , 32.36959845,
#        53.24083969, 46.1491772 , 43.23078   , 56.11676289, 60.30999522,
#        59.31280119, 41.60782477, 46.90787624, 53.31263431, 59.75545127,
#        45.20825762, 48.14341023, 38.93665026, 38.03793376, 58.12525822,
# ...

# %%
group_b
# Out:
# array([40.84629258, 50.79354677, 51.57285483, 46.97722731, 53.38714288,
#        59.04050857, 73.86185901, 56.74577813, 57.57550391, 54.25554084,
#        35.81228785, 54.73486125, 55.6023021 , 79.63242112, 53.07639035,
#        58.01547342, 54.6528823 , 43.31321962, 66.42822815, 62.51933033,
#        62.91031947, 45.90612545, 69.02794311, 40.98148937, 60.86857094,
#        76.90455626, 45.09463675, 49.3370227 , 55.99651365, 49.96524346,
#        39.49336569, 55.68562975, 44.37696286, 59.73592431, 45.80575766,
#        70.49934405, 47.16746708, 51.77938484, 63.13517217, 42.69135684,
#        57.27459935, 68.07142754, 38.92516765, 56.84633859, 57.59882794,
#        62.81822872, 42.63049289, 41.79543387, 60.21941566, 57.96984673,
#        57.5049285 , 58.46448209, 48.19975278, 57.32253697, 57.93072473,
#        47.85648582, 73.65774511, 59.73832921, 43.08696503, 61.56553609,
#        45.2531833 , 62.87084604, 66.58595579, 46.79317682, 64.63376129,
# ...
